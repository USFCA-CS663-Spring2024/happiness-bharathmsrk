# %% [markdown]
# # Assignment 1 - EDA vs. Happiness
#
# ### Steps:
#
# * Understand the data
# * Analyse the data (univariate)
# * Analyse the data (bivariate)
# * Answer given question based on the data
#
# Data Quality Evaluation Report and Answers at the end of the file

# %% [markdown]
# # Part 1 - Understand and analyse the data

# %%
import pandas as pd

# Creating the dataframe
df = pd.read_excel('DataForTable2.1WHR2023.xls')
df
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.350416        0.450662
# 1     Afghanistan  2009     4.401778            7.508646        0.552308
# 2     Afghanistan  2010     4.758381            7.613900        0.539075
# 3     Afghanistan  2011     3.831719            7.581259        0.521104
# 4     Afghanistan  2012     3.782938            7.660506        0.520637
# ...           ...   ...          ...                 ...             ...
# 2194     Zimbabwe  2018     3.616480            7.783066        0.775388
# 2195     Zimbabwe  2019     2.693523            7.697755        0.759162
# 2196     Zimbabwe  2020     3.159802            7.596050        0.717243
# 2197     Zimbabwe  2021     3.154578            7.656878        0.685151
# 2198     Zimbabwe  2022     3.296220            7.670123        0.666172
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %% [markdown]
# # Question 1(a) -
#
# * What is your evaluation of the quality of the data?
#
# The World Happiness Report, emphasizes the global importance of happiness and well-being as a major point of reference for government policy. Life evaluations from the Gallup World Poll form the basis for the annual happiness rankings, where respondents rate their own lives on a scale from 0 to 10. Initiated by Bhutan, the United Nations adopted Resolution 65/309 in 2011, encouraging nations to prioritize happiness in development and is released annually around March 20th.
#
# This report has data from the year 2005 to 2022. There are some missing values and outliers in the data but overall they consider a wide vairety of information. The various features are Country name, year, Life Ladder, Log GDP per capita, Social support, Healthy life expectancy at birth, Freedom to make life choices, Generosity, Perceptions of corruption, Positive affect, Negative affect. There is some normal distribution, left and right skewed data.
#
# A more detailed evaluation is present at the end of the document.

# %%
# Description of data
df.describe()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  2199.000000  2199.000000         2179.000000     2186.000000
# mean   2014.161437     5.479226            9.389766        0.810679
# std       4.718736     1.125529            1.153387        0.120952
# min    2005.000000     1.281271            5.526723        0.228217
# 25%    2010.000000     4.646750            8.499764        0.746609
# 50%    2014.000000     5.432437            9.498955        0.835535
# 75%    2018.000000     6.309460           10.373216        0.904792
# max    2022.000000     8.018934           11.663788        0.987343
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       2145.000000                   2166.000000
# mean                          63.294583                      0.747858
# std                            6.901104                      0.140150
# min                            6.720000                      0.257534
# ...

# %% [markdown]
# # Question 1(a), 1(b)
# * How large is the dataset? What are the features (columns) and how are they represented?

# %%
# Provides the size of the dataset
df.shape
# Out:
# (2199, 11)

# %%
# Provides relevant information on the dataset - size, columns, information on the null values, and the data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      2199 non-null   object
#  1   year                              2199 non-null   int64
#  2   Life Ladder                       2199 non-null   float64
#  3   Log GDP per capita                2179 non-null   float64
#  4   Social support                    2186 non-null   float64
#  5   Healthy life expectancy at birth  2145 non-null   float64
#  6   Freedom to make life choices      2166 non-null   float64
#  7   Generosity                        2126 non-null   float64
#  8   Perceptions of corruption         2083 non-null   float64
#  9   Positive affect                   2175 non-null   float64
#  10  Negative affect                   2183 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# ...

# %%
# Displays all the columns
df.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %%
# Displays the number of missing values in each column
df.isna().sum()
# Out:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                   20
# Social support                       13
# Healthy life expectancy at birth     54
# Freedom to make life choices         33
# Generosity                           73
# Perceptions of corruption           116
# Positive affect                      24
# Negative affect                      16
# dtype: int64

# %% [markdown]
# # Analyse relationships in variables
#
# # Question 1(c)
#
# *  Are there any interesting distributions in the (numeric) features?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

numeric_columns = ['year', 'Life Ladder', 'Log GDP per capita', 'Social support',
                   'Healthy life expectancy at birth', 'Freedom to make life choices',
                   'Generosity', 'Perceptions of corruption', 'Positive affect',
                   'Negative affect']

# %%
plt.figure(figsize=(15, 15))
for i, col in enumerate(numeric_columns, 1):
    plt.subplot(4, 3, i)
    sns.histplot(df[col].dropna(), kde=True)
    plt.title(f'Distribution of {col}')

plt.tight_layout()
plt.show()

# %%
df["Life Ladder"].skew()
# Out:
# -0.017819331787346102

# %%
df["Life Ladder"].kurt()
# Out:
# -0.5918479723083578

# %%
df["Perceptions of corruption"].skew()
# Out:
# -1.4904178416399556

# %%
df["Perceptions of corruption"].kurt()
# Out:
# 1.814231483430651

# %%
df["Generosity"].skew()
# Out:
# 0.7770869685066418

# %%
df["Generosity"].kurt()
# Out:
# 0.8315897969858366

# %% [markdown]
# * From the above graphs, we can infer that all the graphs are normal distribution with some of them being left or right skewed. For example, Life Ladder looks the most normal amongst all. While the negative skewness (-1.4904) and positive kurtosis (1.8142) values suggest that the distribution of the "Perceptions of corruption" column is left-skewed and leptokurtic. And the positive skewness (0.7771) and positive kurtosis (0.8316) values suggest that the distribution of the "Generosity" column is right-skewed and leptokurtic.

# %%
sns.pairplot(df)

# %%
# Example of scatter plot along with a regression line to indicate the linear relationship

life_ladder_data = df['Life Ladder'].dropna()
log_gdp_data = df['Log GDP per capita'].dropna()

life_ladder_data = life_ladder_data[log_gdp_data.index]
log_gdp_data = log_gdp_data[life_ladder_data.index]

plt.figure(figsize=(10, 6))
sns.scatterplot(x=log_gdp_data, y=life_ladder_data, color="skyblue", alpha=0.7, label='Data Points')

sns.regplot(x=log_gdp_data, y=life_ladder_data, scatter=False, color="black", line_kws={'label':'Linear Regression'})

plt.title('Scatter Plot: Life Ladder vs. Log GDP per capita')
plt.xlabel('Log GDP per capita')
plt.ylabel('Life Ladder')
plt.legend()
plt.show()

# %% [markdown]
# There are several pairplots that show somewhat linear relationships.

# %% [markdown]
# # Question 1(d)
#
# * Are there any interesting correlations in the data?

# %%
sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# * There are a lot of strong correlation that we observe from the heatmap -
#     * Life ladder (Happiness) and Log GDP per capita
#     * Life ladder (Happiness) and Social support
#     * Life ladder (Happiness) and Healthy life expectency at birth
#     * Log GDP per capita and year
#     * Log GDP per capita and Healthy life expectency at birth
# * There are several other moderate correlation too in the heatmap.

# %% [markdown]
# # Question 1(e) -
#
# * Can you identify any limitations, missing values or distortions of the data?

# %%
# Number of countries each year - 

df['year'].value_counts().sort_index()
# Out:
# 2005     27
# 2006     89
# 2007    102
# 2008    110
# 2009    114
# 2010    124
# 2011    146
# 2012    141
# 2013    136
# 2014    144
# 2015    142
# 2016    141
# 2017    147
# 2018    141
# 2019    143
# 2020    116
# 2021    122
# 2022    114
# Name: year, dtype: int64

# %% [markdown]
# This shows that in the year 2005 there were only 27 countries. And also changes slightly each year. This can give some small errors while processing this data which could be a limitation.

# %%
# Box Plot for all numeric columns

plt.figure(figsize=(15, 15))
for i, col in enumerate(numeric_columns, 1):
    plt.subplot(4, 3, i)
    sns.boxplot(x=df[col])
    plt.title(f'Box Plot for {col}')

# %% [markdown]
# These boxplots show that there are several outliers in each numeric cloumn and one outlier each in Life Ladder and Log GDP per capita. These outliers must be analyzed to see if they're errors that should be removed or something else.

# %%
# Displays the number of missing values in each column
df.isna().sum()
# Out:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                   20
# Social support                       13
# Healthy life expectancy at birth     54
# Freedom to make life choices         33
# Generosity                           73
# Perceptions of corruption           116
# Positive affect                      24
# Negative affect                      16
# dtype: int64

# %% [markdown]
# There are missing values with the most being in the Perceptions of corruption cloumn.

# %% [markdown]
# # Question 1(f)
# * What would you like to see in this dataset?

# %% [markdown]
# There are other features that I think could be applicable to this dataset -
#
# * Average Income
# * Civil, economic or war-torn crisis
# * Literacy rates
# * More filters to group counties - for example - Continents/Region
# * Population

# %% [markdown]
# # Part 2 -
# # Answer to Question 2

# %%
# What is the happiest country in 2022?

happiest_country_22 = df[df['year'] == 2022].loc[df[df['year'] == 2022]['Life Ladder'].idxmax(), 'Country name']
print(f"The happiest country in 2022 is: {happiest_country_22}")
# Out:
# The happiest country in 2022 is: Finland

# %%
# What is the happiest country in 2013?

happiest_country_13 = df[df['year'] == 2013].loc[df[df['year'] == 2013]['Life Ladder'].idxmax(), 'Country name']
print(f"The happiest country in 2013 is: {happiest_country_13}")
# Out:
# The happiest country in 2013 is: Canada

# %%
# What is the happiest country of all time?

happiest_country = df.loc[df['Life Ladder'].idxmax(), 'Country name']
print(f"The happiest country of all time is: {happiest_country}")
# Out:
# The happiest country of all time is: Denmark

# %%
# What is the least happy country in 2022?

least_happy_country_22 = df[df['year'] == 2022].loc[df[df['year'] == 2022]['Life Ladder'].idxmin(), 'Country name']
print(f"The least happy country in 2022 is: {least_happy_country_22}")
# Out:
# The least happy country in 2022 is: Afghanistan

# %%
# What is the least happy country in 2013?

least_happy_country_13 = df[df['year'] == 2013].loc[df[df['year'] == 2013]['Life Ladder'].idxmin(), 'Country name']
print(f"The least happy country in 2013 is: {least_happy_country_13}")
# Out:
# The least happy country in 2013 is: Syria

# %%
# What is the least happy country of all time?

least_happy_country = df.loc[df['Life Ladder'].idxmin(), 'Country name']
print(f"The least happy country of all time is: {least_happy_country}")
# Out:
# The least happy country of all time is: Afghanistan

# %% [markdown]
# # Part 3 -
# # Answer to Question 3

# %%
# Country with the largest increase in happiness

df = df.sort_values(by=["Country name", "year"])

first_year_happiness = df.groupby("Country name")["Life Ladder"].first()
last_year_happiness = df.groupby("Country name")["Life Ladder"].last()

percentage_change = ((last_year_happiness - first_year_happiness) / first_year_happiness) * 100

max_change_country = percentage_change.idxmax()
max_change_value = percentage_change.max()

print(f"Country with the largest percentage increase in happiness is {max_change_country} with an increase of {max_change_value:.2f}%.")
# Out:
# Country with the largest percentage increase in happiness is Congo (Brazzaville) with an increase of 51.97%.

# %%
# Country with the largest decrease in happiness

max_decrease_country = percentage_change.idxmin()
max_decrease_value = percentage_change.min()

print(f"The country with the largest decrease in happiness is {max_decrease_country} with a decrease of {max_decrease_value:.2f}.")
# Out:
# The country with the largest decrease in happiness is Afghanistan with a decrease of -65.59.

# %% [markdown]
# # Overall Data Quality Evaluation and Answers
#
# * The dataframe has 2199 entries and a total of 11 columns.
# * Most of the columns are represented as float with the exception of country name (String) and year (int)
# * There are a few missing values in all columns expect country name, year and life ladder. And with the most in Perception of Corruption (~5%).
# * All the numeric features (columns) are normal distributed but some of them like Social support, Freedom to make life choices, Perceptions of corruption, etc are skewed normal distribution. For example, Life Ladder looks the most normal amongst all. While the negative skewness (-1.4904) and positive kurtosis (1.8142) values suggest that the distribution of the "Perceptions of corruption" column is left-skewed and leptokurtic. And the positive skewness (0.7771) and positive kurtosis (0.8316) values suggest that the distribution of the "Generosity" column is right-skewed and leptokurtic.
# * Majority of the countries have some form of social support (>0.5)
# * The life ladder is alomost perfectly normal distributed with a minimum score of approximately 1 and maximum score of approximately 8 with most counties scoring between 3 and 8.
# * It is also noted that perception of corruption is significant in most of the counties and is left-skewed.
# * There are several pairplots that show somewhat linear relationships, for example, life ladder vs Log GDP per capita.
# * There are a lot of strong correlation that we observe from the heatmap -
#     * Life ladder (Happiness) and Log GDP per capita
#     * Life ladder (Happiness) and Social support
#     * Life ladder (Happiness) and Healthy life expectency at birth
#     * Log GDP per capita and year
#     * Log GDP per capita and Healthy life expectency at birth
# * There are several other moderate correlation too in the heatmap.
# * Interesting to note that generosity is not strongly coorelated as one might usually think happier people are more generous.
# * These boxplots show that there are several outliers in each numeric cloumn and one outlier each in Life Ladder and Log GDP per capita. These outliers must be analyzed to see if they're errors that should be removed before further processing.
# * There are other features that I think could be applicable to this dataset -
#     * Average Income
#     * Civil/economic or war-torn crisis
#     * Literacy rates
#     * More filters to group counties - for example - Continents/Region
#     * Population
# * Answers to question 2 -
#     * Happiest country in 2022 - Finland
#     * Happiest country in 2013 - Canada
#     * Happiest country of all time - Denmark
#     * Least happy country in 2022 - Afghanistan
#     * Least happy country in 2013 - Syria
#     * Least happy country of all time - Afghanistan
# * Answers to question 3 -
#     * Largest increase in happiness - Congo (Brazzaville)
#     * Largest decrease in happiness - Afghanistan
